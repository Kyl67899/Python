# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyl67899/Python/blob/work/Data_Scientist_with_Python_w_AI_planet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science
# ##### Credit to code and information came from Ai Planet
# ####Copyright: All reights are reserved
# #####Credit: Kyle Yarun Parsotan

# %% [markdown]
# ## Intro to Data Science

# %%
print("Hello, DPhi! Today I excuted my first Python program. Thanks! ")
# Out:
# Hello, DPhi! Today I excuted my first Python program. Thanks!

# %%
# Consider two numbers, a = 5, b = 16. Write a Python program to print the sum of these two numbers.
# Write a Python program to take a number from the user as input and print the cube of the number.

# %%
a = 5 

b = 16

x = a + b
print(x)
# Out:
# 21

# %%
u = int(input("Pick a number: "))

z = u ** 3

print(z)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-cbcaa8ac66c3> in <module>
# ----> 1 u = int(input("Pick a number: "))
#       2
#       3 z = u ** 3
#       4
#       5 print(z)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %%
#Functions

y = [2, 4, 6, 1, 9]

max(y)

# %%
len(y)

# %%
round(2.34, 1)

# %%
sorted(y, reverse=True)

# %%
y.index(1)

# %%
y.count(4)

# %%
word = 'msdemfds'

word.capitalize()

# %%
word.replace("dem", "efg")

# %% [markdown]
# ##Intro to Pandas

# %%
#pandas
import pandas as pd

# %%
exams = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data_science/exam_scores.csv")

# %%
#shape attribute

exams.shape
# Out:
# (1000, 8)

# %%
#use head method

exams.head(3)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65

# %%
#tail method #last 5 instead of first 5

exams.tail(3)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 997                    none          67             67             67
# 998                    none          63             68             70
# 999                    none          49             57             50

# %%
#data types

exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
exams.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2      male        group C                some college  free/reduced
# 3    female        group D           bachelor's degree  free/reduced
# 4      male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group C            some high school      standard
# 996  female        group E                some college      standard
# 997  female        group E          associate's degree  free/reduced
# 998  female        group C                 high school      standard
# 999    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
exams.iloc[-4:, 0:2]
# Out:
#      gender race/ethnicity
# 996  female        group E
# 997  female        group E
# 998  female        group C
# 999    male        group C

# %%
exams["test preparation course"]
# Out:
# 0           none
# 1      completed
# 2           none
# 3           none
# 4           none
#          ...
# 995         none
# 996         none
# 997         none
# 998         none
# 999         none
# Name: test preparation course, Length: 1000, dtype: object

# %%
exams[["gender", "test preparation course"]]
# Out:
#      gender test preparation course
# 0      male                    none
# 1    female               completed
# 2      male                    none
# 3    female                    none
# 4      male                    none
# ..      ...                     ...
# 995  female                    none
# 996  female                    none
# 997  female                    none
# 998  female                    none
# 999    male                    none
#
# [1000 rows x 2 columns]

# %%
exams[exams.lunch == 'standard']
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0      male        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 4      male        group D                some college  standard
# 5    female        group D          associate's degree  standard
# 8      male        group C            some high school  standard
# ..      ...            ...                         ...       ...
# 993    male        group A                some college  standard
# 994    male        group C             master's degree  standard
# 995  female        group C            some high school  standard
# 996  female        group E                some college  standard
# 998  female        group C                 high school  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          74             68             67
# ...

# %%
exams.describe(include = 'all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       502            294                         226       649
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course   math score  reading score  writing score
# count                     1000  1000.000000     1000.00000    1000.000000
# ...

# %%
exams["math score"].sort_values()[:10]
# Out:
# 949    15
# 854    18
# 891    23
# 349    25
# 739    25
# 316    28
# 310    30
# 413    31
# 117    31
# 649    31
# Name: math score, dtype: int64

# %%
exams.rename(columns= {"race/ethnicity": "race", 
                       "parental level of education": "parental_level_of_education",
                       "test preparation course": "test_preparation_course",
                       "math score": "math_score", 
                       "reading score": "reading_score", 
                       "writing score": "writing_score"}, inplace=True)

# %%
exams.columns
# Out:
# Index(['gender', 'race', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
exams.head()
# Out:
#    gender     race parental_level_of_education         lunch  \
# 0    male  group B           bachelor's degree      standard
# 1  female  group C                some college      standard
# 2    male  group C                some college  free/reduced
# 3  female  group D           bachelor's degree  free/reduced
# 4    male  group D                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          74             68             67
# 1               completed          58             68             66
# 2                    none          66             65             65
# 3                    none          74             75             73
# 4                    none          78             77             71

# %%
exams.isnull().sum()
# Out:
# gender                         0
# race                           0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# ## Quiz 1

# %%
#import pandas
import pandas as pd

#read in data 
ckd_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Chronic%20Kidney%20Disease%20(CKD)%20Dataset/ChronicKidneyDisease.csv")
#print data
ckd_data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
ckd_data.head(10)
# Out:
#    id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0   0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1   1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2   2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3   3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4   4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5   5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6   6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7   7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8   8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9   9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
#
#            ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44   7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38   6000  NaN   no   no   no  good   no   no
# ...

# %%
ckd_data.tail(7)
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 393  393  43.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 394  394  50.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 393  ...   54  7400  5.4   no  no   no  good  no  no         notckd
# 394  ...   45  9500  4.6   no  no   no  good  no  no         notckd
# 395  ...   47  6700  4.9   no  no   no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# ...

# %%
ckd_data.dtypes
# Out:
# Id                  int64
# Age               float64
# blood_pressure    float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
ckd_data.describe()
# Out:
#                Id         Age  blood_pressure          sg          al  \
# count  400.000000  391.000000      388.000000  353.000000  354.000000
# mean   199.500000   51.483376       76.469072    1.017408    1.016949
# std    115.614301   17.169714       13.683637    0.005717    1.352679
# min      0.000000    2.000000       50.000000    1.005000    0.000000
# 25%     99.750000   42.000000       70.000000    1.010000    0.000000
# 50%    199.500000   55.000000       80.000000    1.020000    0.000000
# 75%    299.250000   64.500000       80.000000    1.020000    2.000000
# max    399.000000   90.000000      180.000000    1.025000    5.000000
#
#                su         bgr          bu          sc         sod         pot  \
# count  351.000000  356.000000  381.000000  383.000000  313.000000  312.000000
# mean     0.450142  148.036517   57.425722    3.072454  137.528754    4.627244
# std      1.099191   79.281714   50.503006    5.741126   10.408752    3.193904
# ...

# %%
ckd_data.loc[247:254, ["id", "age", "classification"]]
# Out:
#       id   age classification
# 247  247  54.0            ckd
# 248  248  59.0            ckd
# 249  249  56.0            ckd
# 250  250  40.0         notckd
# 251  251  23.0         notckd
# 252  252  45.0         notckd
# 253  253  57.0         notckd
# 254  254  51.0         notckd

# %%
ckd_data.max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# id                   399
# age                 90.0
# bp                 180.0
# sg                 1.025
# al                   5.0
# su                   5.0
# bgr                490.0
# bu                 391.0
# sc                  76.0
# sod                163.0
# pot                 47.0
# hemo                17.8
# classification    notckd
# dtype: object

# %%
ckd_data.rename(columns = {
   "id": "Id",
   "age": "Age",
   "bp": "blood_pressure",
}, inplace=True)
ckd_data
# Out:
#       Id   Age  blood_pressure     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0            80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0            50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0            80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0            70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0            80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...             ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0            80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0            70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0            80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0            60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0            80.0  1.025  0.0  0.0  normal    normal  notpresent
#
# ...

# %%
ckd_data[["Id", "Age", "classification"]].isna().sum()
# Out:
# Id                0
# Age               9
# classification    0
# dtype: int64

# %%
ckd_data[["blood_pressure"]].isna().sum()
# Out:
# blood_pressure    12
# dtype: int64

# %%
ckd_data
# Out:
#       Id   Age  blood_pressure     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0            80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0            50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0            80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0            70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0            80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...             ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0            80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0            70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0            80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0            60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0            80.0  1.025  0.0  0.0  normal    normal  notpresent
#
# ...

# %%
ckd_data["cad"].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     719         try:
# --> 720             values = values.astype("f8")
#     721         except ValueError as err:
#
# ValueError: could not convert string to float: 'no'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-7bcdca78325a> in <module>
# ----> 1 str(ckd_data["cad"].median())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   10800             self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs
#   10801         ):
# ...

# %%
ckd_data["blood_pressure"].fillna(ckd_data["blood_pressure"].median(), inplace=True)
ckd_data.describe()
# Out:
#                Id         Age  blood_pressure          sg          al  \
# count  400.000000  391.000000      400.000000  353.000000  354.000000
# mean   199.500000   51.483376       76.575000    1.017408    1.016949
# std    115.614301   17.169714       13.489785    0.005717    1.352679
# min      0.000000    2.000000       50.000000    1.005000    0.000000
# 25%     99.750000   42.000000       70.000000    1.010000    0.000000
# 50%    199.500000   55.000000       80.000000    1.020000    0.000000
# 75%    299.250000   64.500000       80.000000    1.020000    2.000000
# max    399.000000   90.000000      180.000000    1.025000    5.000000
#
#                su         bgr          bu          sc         sod         pot  \
# count  351.000000  356.000000  381.000000  383.000000  313.000000  312.000000
# mean     0.450142  148.036517   57.425722    3.072454  137.528754    4.627244
# std      1.099191   79.281714   50.503006    5.741126   10.408752    3.193904
# ...

# %%
ckd_data["cad"].fillna(ckd_data["cad"].mean(), inplace=True)
ckd_data.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-61599df76778> in <module>
# ----> 1 ckd_data["cad"].fillna(ckd_data["cad"].mean(), inplace=True)
#       2 ckd_data.describe()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# ...

# %%
ckd_data.to_csv("test.csv", index=False)

# %%
#read in data 
ckd_data = pd.read_csv("test.csv")
#print data
ckd_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Id   Age  blood_pressure     sg   al   su  \
# 0           0             0   0  48.0            80.0  1.020  1.0  0.0
# 1           1             1   1   7.0            50.0  1.020  4.0  0.0
# 2           2             2   2  62.0            80.0  1.010  2.0  3.0
# 3           3             3   3  48.0            70.0  1.005  4.0  0.0
# 4           4             4   4  51.0            80.0  1.010  2.0  0.0
#
#       rbc        pc  ... pcv    wc   rc  htn   dm  cad  appet   pe  ane  \
# 0     NaN    normal  ...  44  7800  5.2  yes  yes   no   good   no   no
# 1     NaN    normal  ...  38  6000  NaN   no   no   no   good   no   no
# 2  normal    normal  ...  31  7500  NaN   no  yes   no   poor   no  yes
# 3  normal  abnormal  ...  32  6700  3.9  yes   no   no   poor  yes  yes
# 4  normal    normal  ...  35  7300  4.6   no   no   no   good   no   no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3            ckd
# ...
